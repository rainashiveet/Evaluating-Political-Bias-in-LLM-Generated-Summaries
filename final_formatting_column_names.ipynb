# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("final_merged_all_models_updated.csv")

# Rename columns
df = df.rename(columns={
    "bert_extractive_summary": "Extractive_Summary",
    "claude_abstractive_summary": "Claude_Summary",
    "gemini_abstractive_summary": "Gemini_Summary",
    "gpt4o_abstractive_summary": "GPT4o_Summary",
    "llama_abstractive_summary": "Llama_Summary",
    "mistral_abstractive_summary": "Mistral_Summary",
    "deepseek_abstractive_summary": "DeepSeek_Summary"
})

# Save new CSV
df.to_csv("TheFinal.csv", index=False)

print("✅ Columns renamed and file saved as TheFinal.csv")
# Out:
# ✅ Columns renamed and file saved as TheFinal.csv
